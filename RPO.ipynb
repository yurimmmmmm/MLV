# %% [markdown]
# <a href="https://colab.research.google.com/github/yurimmmmmm/MLV/blob/main/RPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
# my_path = '/content/notebooks'
# # Colab Notebooks 안에 my_env 폴더에 패키지 저장
# os.symlink('/content/drive/My Drive/Colab Notebooks/my_env', my_path)
# sys.path.insert(0, my_path)
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/My Drive"
# Out:
# /content/drive/My Drive

# %%
# !git clone https://github.com/mlvlab/RPO.git
# Out:
# fatal: destination path 'RPO' already exists and is not an empty directory.

# %%
cd "RPO"
# Out:
# /content/drive/My Drive/RPO

# %%
# !git clone https://github.com/KaiyangZhou/Dassl.pytorch.git
# Out:
# fatal: destination path 'Dassl.pytorch' already exists and is not an empty directory.

# %%
 cd "./Dassl.pytorch"
# Out:
# /content/drive/My Drive/RPO/Dassl.pytorch

# %%
# !pip install -r requirements.txt
# !python setup.py develop
# !pip install regex
# !pip install ftfy
# !pip install tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.3/185.3 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 12.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7026 sha256=45e37cbb8bea38c738642d9f4372518d96e37bf219612d5c46ef53960d481f0f
# ...

# %%
cd ..
# Out:
# /content/drive/My Drive/RPO

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1512= DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 1
# Out:
# 2024-02-28 08:51:42.768148: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 08:51:42.768200: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 08:51:42.769527: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-28 08:51:42.776445: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1512= DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.CTX_INIT: ""
# Out:
# 2024-02-28 08:51:42.768148: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 08:51:42.768200: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 08:51:42.769527: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-28 08:51:42.776445: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep1512= --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1512= --load-epoch 15 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new TRAINER.RPO.K 1
# Out:
# 2024-02-28 09:05:56.050438: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 09:05:56.050495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 09:05:56.051913: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-28 09:05:56.059493: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep15sa1 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.CTX_INIT "a satellite photo of"
# Out:
# 2024-02-28 09:20:59.478995: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 09:20:59.479043: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 09:20:59.480261: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-28 09:20:59.487038: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 3 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep15sa1 --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep15saa --load-epoch 15 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new TRAINER.RPO.CTX_INIT "a satellite photo of a"
# Out:
# 2024-02-28 09:38:44.750010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 09:38:44.750057: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 09:38:44.751457: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-28 09:38:44.759059: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep15saa DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.CTX_INIT "a satellite photo of a"
# Out:
# 2024-02-28 09:28:24.325309: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 09:28:24.325362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 09:28:24.326725: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-28 09:28:24.333868: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep156 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 6
# Out:
# 2024-02-26 13:58:27.424147: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:58:27.424211: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:58:27.425502: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:58:27.432617: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 3 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep151222 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 12
# Out:
# 2024-02-26 13:08:43.535864: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:08:43.535918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:08:43.537274: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:08:43.544459: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 3 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep151222 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 12
# Out:
# 2024-02-26 13:08:43.535864: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:08:43.535918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:08:43.537274: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:08:43.544459: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1560 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 60
# Out:
# 2024-02-26 14:14:32.210709: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 14:14:32.210760: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 14:14:32.212109: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 14:14:32.219198: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 3 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep151222 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 12
# Out:
# 2024-02-26 13:08:43.535864: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:08:43.535918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:08:43.537274: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:08:43.544459: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 3 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep156 --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep156 --load-epoch 15 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new TRAINER.RPO.K 6
# Out:
# 2024-02-26 14:10:16.646618: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 14:10:16.646684: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 14:10:16.648378: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 14:10:16.657978: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 3 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep151222 --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep151222 --load-epoch 15 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new TRAINER.RPO.K 12
# Out:
# 2024-02-26 13:30:53.338040: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:30:53.338094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:30:53.339470: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:30:53.346610: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep1560 --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1560 --load-epoch 15 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new TRAINER.RPO.K 60
# Out:
# 2024-02-26 14:27:41.726935: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 14:27:41.726987: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 14:27:41.728349: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 14:27:41.735421: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep1548 --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1548 --load-epoch 15 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new TRAINER.RPO.K 48
# Out:
# 2024-02-26 13:50:13.295339: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:50:13.295387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:50:13.296718: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:50:13.303850: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1596 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 96
# Out:
# 2024-02-26 13:52:05.460335: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:52:05.460387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:52:05.461655: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:52:05.469332: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1548 DATASET.NUM_SHOTS  16 DATASET.SUBSAMPLE_CLASSES base TRAINER.RPO.K 48
# Out:
# 2024-02-26 13:40:06.777568: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 13:40:06.777637: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 13:40:06.779062: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 13:40:06.786461: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep1 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base OPTIM.MAX_EPOCH 1

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ktt DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base OPTIM.MAX_EPOCH 50
# Out:
# 2024-02-23 01:16:08.810294: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 01:16:08.810349: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 01:16:08.811923: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 01:16:08.819689: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ktt --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ktt --load-epoch 50 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new
# Out:
# 2024-02-23 02:04:26.791578: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 02:04:26.791630: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 02:04:26.794013: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 02:04:26.804474: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 2  --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ktt --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ktt --load-epoch 50 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new
# Out:
# 2024-02-23 02:20:47.372002: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 02:20:47.372052: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 02:20:47.373344: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 02:20:47.380459: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
ls
# Out:
# clip/     Dassl.pytorch/  DATASETS.md  LICENSE  parse_test_res.py  requirements.txt  trainers/
# configs/  datasets/       figures/     output/  README.md          scripts/          train.py

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/seed3 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base
# Out:
# 2024-02-21 12:05:42.976455: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-21 12:05:42.976501: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-21 12:05:42.977835: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-21 12:05:42.985240: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep30 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base OPTIM.MAX_EPOCH 30
# Out:
# 2024-02-23 02:24:38.951293: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 02:24:38.951348: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 02:24:38.952767: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 02:24:38.960032: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep30 --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep30 --load-epoch 30 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new
# Out:
# 2024-02-23 02:39:10.047843: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 02:39:10.047895: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 02:39:10.049211: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 02:39:10.056231: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 2 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/test_new/eurosat/shots_16/RPO/main_K24/ep30 --model-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep30 --load-epoch 30 --eval-only DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES new
# Out:
# 2024-02-23 02:42:28.333376: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 02:42:28.333424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 02:42:28.334766: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 02:42:28.341912: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python train.py --root ../ --seed 1 --trainer RPO --dataset-config-file configs/datasets/eurosat.yaml --config-file configs/trainers/RPO/main_K24.yaml --output-dir output/rpo/base2new/train_base/eurosat/shots_16/RPO/main_K24/ep15 DATASET.NUM_SHOTS 16 DATASET.SUBSAMPLE_CLASSES base
